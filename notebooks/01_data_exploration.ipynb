# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/amazon_reviews.csv")

print("Dataset loaded successfully!")

# %%
df.head()

# %%
df.shape

# %%
df.columns.tolist()

# %%
df.info()

# %%
df.isnull().sum()
